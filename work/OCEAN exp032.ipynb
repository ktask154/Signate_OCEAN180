# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

DIR = "/content/drive/MyDrive/Competitions/Signate/OCEAN180"
INPUT_DIR = os.path.join(DIR,"input")
OUTPUT_DIR = os.path.join(DIR,"output")

if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
train = pd.read_csv(os.path.join(INPUT_DIR,"train_data.csv"))
test = pd.read_csv(os.path.join(INPUT_DIR,"test_data.csv"))
sample_sub = pd.read_csv(os.path.join(INPUT_DIR,"submit_example.csv"), header=None)

print(train.shape)
display(train.head(3))

print(test.shape)
display(test.head(3))

print(sample_sub.shape)
display(sample_sub.head(3))
# Out:
# (14140, 3465)
#    Unnamed: 0        lat         lon  area                 YMD    year  month  \
# 0           0  24.989139  125.243167  20.0            20110926  2011.0    9.0
# 1           1  26.996172  127.912024  40.0  2009.7.6-2009.7.28  2009.0    7.0
# 2           2  26.363556  127.735139  20.0            20091014  2009.0   10.0
#
#    cover  depth_original  cliff_length  ...  MIN_NormG_2020  MIN_NormR_2020  \
# 0  0.050             NaN           0.0  ...        0.507961        0.287288
# 1  0.725             NaN           0.0  ...        0.353645        0.245048
# 2  0.025             NaN           0.0  ...        0.579204        0.281260
#
#    MIN_PPR_2020  MIN_PSNDc2_2020  MIN_RDVI_2020  MIN_IF_2020  MIN_SLAVI_2020  \
# 0     -0.278071        -0.808075      -2.341663     2.353039       95.142525
# 1     -0.100556        -0.771423      -3.282602     4.672225      174.767501
# 2     -0.191884        -0.853730      -3.160207     3.324236       62.711236
#
#    MIN_SIPI2_2020  MIN_VARIgreen_2020   mesh20
# 0        3.728732           -2.405135  3725_10
# 1       -0.571513            0.448861  4027_13
# 2        3.284478          -57.136191  3927_22
#
# [3 rows x 3465 columns]
# (4039, 3464)
#    Unnamed: 0        lat         lon   area  \
# 0           0  24.352222  124.202674   20.0
# 1           1  24.420028  124.078583   20.0
# 2           2  26.494197  127.836013  100.0
#
#                                                  YMD    year  month  \
# 0                                            2002.12  2002.0   12.0
# 1                                           20100723  2010.0    7.0
# 2  2004.2.20-2004.2.22,2004.2.27-2004.2.29,2004.3...  2004.0    2.0
#
#    depth_original  cliff_length  aicial_length  ...  MIN_NormG_2020  \
# 0             0.5      0.000000     725.621704  ...        0.409346
# 1             NaN      0.000000       0.000000  ...        0.540733
# 2            13.8     73.183418      80.595177  ...        0.601792
#
#    MIN_NormR_2020  MIN_PPR_2020  MIN_PSNDc2_2020  MIN_RDVI_2020  MIN_IF_2020  \
# 0        0.323023     -0.066356        -0.560810      -3.203797     4.297234
# 1        0.275585     -0.291240        -0.824888      -2.222276     2.263106
# 2        0.252251     -0.318454        -0.861477      -2.060505     2.099250
#
#    MIN_SLAVI_2020  MIN_SIPI2_2020  MIN_VARIgreen_2020   mesh20
# 0      926.905329        1.669992            0.194766  3624_20
# 1       57.661693        4.274851          -79.273275  3624_20
# 2       42.672829        5.655713           -2.061417  3927_23
#
# [3 rows x 3464 columns]
# (4039, 2)
#    0     1
# 0  0  0.47
# 1  1  0.68
# 2  2  0.25

# %%
train.rename(columns={"Unnamed: 0":"id"}, inplace=True)
test.rename(columns={"Unnamed: 0":"id"}, inplace=True)

# %%
def missing_func(df):
  total = df.isnull().sum().sort_values(ascending=False)
  percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
  df_missing = pd.concat([total,percent],axis=1,keys=['total','percent'])
  return df_missing

# %%
train_missing = missing_func(train)
test_missing = missing_func(test)

# %%
train_cols = train.columns.tolist()
test_cols = test.columns.tolist()

target = set(train_cols) - set(test_cols)
print(target)

display(train[target].head(3))
# Out:
# {'cover'}
#    cover
# 0  0.050
# 1  0.725
# 2  0.025

# %%
train_area_mean = train.area.mean()
test_area_mean = test.area.mean()
area_mean = (train_area_mean + test_area_mean) / 2
train["area"] = train["area"].fillna(area_mean)
test["area"] = test["area"].fillna(area_mean)

train["cover_area"] = train.cover * train.area
train["cover_area_log"] = np.log1p(train['cover_area'])

# %%
sns.distplot(train["cover_area_log"])

print("max : %f" %train["cover_area_log"].max())
print("min : %f" %train["cover_area_log"].min())
print('Skewness: %f' %train["cover_area_log"].skew())  #歪度
print('Kurtosis: %f' %train["cover_area_log"].kurt())  #尖度
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# max : 3.713572
# min : 0.000000
# Skewness: 1.030917
# Kurtosis: -0.204865

# %%
train["adv_flag"] = 0
test["adv_flag"] = 1

df = pd.concat([train,test]).reset_index(drop=True)

# %%
train_missing_50 = train_missing[train_missing.percent<0.5].index
test_missing_50 =  test_missing[test_missing.percent<0.5].index

categorical_features = train.dtypes[train.dtypes=="object"].index

features = set(train_missing_50) & set(test_missing_50)
features = set(features) - set(categorical_features)

# %%
len(features)
# Out:
# 3159

# %%
land_sat_feats = []
for years in list(range(2000,2021)):
  n_f = [col for col in features if str(years) in col]
  land_sat_feats += n_f
features = [col for col in features if col not in land_sat_feats]

# %%
len(features)
# Out:
# 309

# %%
from sklearn.model_selection import TimeSeriesSplit, StratifiedKFold

fig, axes = plt.subplots(8, 1, figsize=(12, 12))

df['year-month'] = df.year.astype(int).astype(str) + '-' + df.month.astype(int).astype(str)
df['year-month'] = pd.to_datetime(df['year-month'], format='%Y-%m')
df = df.sort_values("year-month").reset_index(drop=True)

folds = StratifiedKFold(n_splits=8,shuffle=False)

for i, (train_index, test_index) in enumerate(folds.split(df,df["adv_flag"])):

    #sns.lineplot(data=train, x='year-month', y='cover', ax=axes[i], label='original')
    # 学習用データを描く
    sns.lineplot(data=df.iloc[train_index], x='year-month', y='cover', ax=axes[i], label='train')
    # テスト用データを描く
    sns.lineplot(data=df.iloc[test_index], x='year-month', y='cover', ax=axes[i], label='test')

# グラフを表示する
plt.legend()
plt.show()

# %% [markdown]
# ## Model

# %%
#!pip install iterative-stratification

# %%
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold, GroupKFold, StratifiedGroupKFold, KFold
#from iterstrat.ml_stratifiers import MultilabelStratifiedKFold
from sklearn.metrics import mean_squared_error
from sklearn.metrics import f1_score, precision_score, recall_score, auc

# %%
class CFG:
  ver=32
  model="lightgbm"
  n_folds=8
  trn_fold=[0, 1, 2, 3, 4, 5, 6, 7]
  seed=42
  target_cols1="adv_flag"
  target_cols2="cover"
  boosting_type="gbdt"
  fold_target1="adv_flag"
  fold_target2="cover"
  fold_target3="cover"

# %%
# =========================================================================================
# CV split
# =========================================================================================
def get_fold(df, fold_target, isFlag=False):
  if isFlag:
    Fold = StratifiedKFold(n_splits=CFG.n_folds, shuffle=False)
    for n, (train_index, val_index) in enumerate(Fold.split(df, df[fold_target])):
        df.loc[val_index, 'fold'] = int(n)
  else:
    Fold = KFold(n_splits=CFG.n_folds, shuffle=False)
    for n, (train_index, val_index) in enumerate(Fold.split(df)):
      df.loc[val_index, 'fold'] = int(n)
    df["fold"] = df["fold"].astype(int)
    display(df.groupby('fold').size())
  return df

# %%
def get_score(labels, preds, isFlag=False):
  if isFlag:
    f1score = f1_score(labels, preds)
    pscore = precision_score(labels, preds)
    rscore =recall_score(labels, preds)
    print(f"F1 Score : {f1score}")
    print(f"Precision Score : {pscore}")
    print(f"Recall Score {rscore}")
  else:
    rmse = np.sqrt(mean_squared_error(labels, preds))
    print(f"RMSE {rmse}")

# %%
#features = list(features)
features.remove('id')
features.remove('area')
features.remove("year")
#features.remove("month")
features.append("mesh20")

# %%
params1 = {
        'objective': "binary",
        'metric': 'auc',
        'learning_rate': 0.1,
        'boosting': CFG.boosting_type,
        'seed': CFG.seed,
        "reg_alpha":0.5,
        "n_estimators":1000
    }

params2 = {
        'objective': 'regression',
        'metric': 'rmse',
        'learning_rate': 0.1,
        'boosting': CFG.boosting_type,
        'seed': CFG.seed,
        "reg_alpha":0.5,
        "n_estimators":1000
    }

# %%
def get_pred(df, test, fold_target, target_cols, model, isFlag=False):
  if isFlag:
    pred_name = "flag"
    train = get_fold(df, fold_target, isFlag=True)
  else:
    pred_name = ""
    train = get_fold(df, fold_target, isFlag=False)
  oof_df = pd.DataFrame()
  df_importance = pd.DataFrame({'feature': features})
  df_importance['importance'] = 0
  test_preds = np.zeros((len(test), CFG.n_folds))

  ctg_list = ["year","month","mesh20"]

  for fold in range(CFG.n_folds):
    if fold in CFG.trn_fold:
      print("="*15,f" FOLD : {fold} ","="*15)
      train_folds = train[train['fold'] != fold]
      valid_folds = train[train['fold'] == fold]

      print(f"train period : {str(train_folds.iloc[0].year)}年{str(train_folds.iloc[0].month)}月 ～ {str(train_folds.iloc[-1].year)}年{str(train_folds.iloc[-1].month)}月")
      print(f"valid period : {str(valid_folds.iloc[0].year)}年{str(valid_folds.iloc[0].month)}月 ～ {str(valid_folds.iloc[-1].year)}年{str(valid_folds.iloc[-1].month)}月")


      train_X = train_folds[features].values
      valid_X = valid_folds[features].values
      test_X = test[features].values
      train_labels = train_folds[target_cols].values
      valid_labels = valid_folds[target_cols].values

      clf = model
      #model = lgb.LGBMRegressor(**params)
      clf.fit(train_X, train_labels,
              eval_set=[(valid_X, valid_labels)],
              #eval_metric="rmse",
              #categorical_feature = ctg_list,
              verbose = 200,
              early_stopping_rounds=50)
      
      if isFlag:
        pred = model.predict(valid_X)
        predict_proba = model.predict_proba(valid_X)
        valid_folds["Zscore"] = predict_proba[:,1]
        valid_folds[f"{pred_name}_pred"] = pred
      else:
        valid_folds[f"{pred_name}_pred"] = model.predict(valid_X)
        test_preds[:, fold] = model.predict(test_X)
      oof_df = pd.concat([oof_df, valid_folds])

      f_importance = np.array(model.feature_importances_)
      temp_importance = pd.DataFrame({'feature': features, 'importance': f_importance})
      df_importance['importance'] += temp_importance['importance']

      get_score(valid_labels, valid_folds[f"{pred_name}_pred"], isFlag)

  df_importance['importance'] = df_importance['importance'] / np.sum(df_importance['importance'])
  df_importance = df_importance.sort_values('importance', ascending=False)
  display(df_importance.head(35))
  fig = plt.figure(figsize=(16, 32), tight_layout=True)
  sns.barplot(x="importance", y="feature", data=df_importance.head(35))
  plt.title("LightGBM feature importances")
  get_score(oof_df[target_cols], oof_df[f"{pred_name}_pred"], isFlag)
  if isFlag:
    return oof_df, df_importance
  else:
    return oof_df,  test_preds

# %%
# 傾向スコアマッチング関数
def matching(result1, z_col='Zscore', tr_col="adv_flag", match_id='id'):
    '''
    result1: 介入変数、傾向スコア、共変量のデータフレーム
    '''
    # キャリパー設定
    caliper = result1[z_col].std()*0.2

    # 処置群抽出
    Tr = result1[result1[tr_col]>0][[match_id, z_col]].copy().reset_index(drop=True)
    Tr.index = Tr[match_id]
    # 対照群抽出
    Ctl = result1[result1[tr_col]==0][[match_id, z_col]].copy().reset_index(drop=True)
    Ctl.index = Ctl[match_id]
    
    Ctl_vals = np.copy(Ctl[z_col].to_numpy()) # 配列化
    Ctl_ids = np.copy(Ctl.index.to_numpy()) # 配列化
    Tr_vals_dict = Tr[z_col].sort_values(ascending=False).to_dict() # 処置群の傾向スコアで降順にして辞書化

    # マッチングを実施していく
    match_results = [] # 結果を入れる箱
    for i, (cid, tr_val) in tqdm(enumerate(Tr_vals_dict.items())):
        # cid:user_id, tr_val:傾向スコア
        # argminで処置群と最も傾向スコアの差が小さい対照群のインデックス番号取得
        nearId = np.abs(Ctl_vals - tr_val).argmin()
        # 傾向スコアの差がキャリパーより大きかった場合、マッチングしない
        if np.abs(tr_val-Ctl_vals[nearId])>caliper:
            continue
        # 傾向スコアの差がキャリパーより小さかった場合、マッチングした者同士をリストに格納
        match_results.append([cid, Ctl_ids[nearId], tr_val, Ctl_vals[nearId]])
        # 次のマッチングで重複してマッチングしないように対照群のスコアを-9999に置き換える
        np.put(Ctl_vals, [nearId], -9999)

    # リストをdf化
    match_results_df = pd.DataFrame(match_results, columns=['Tr', 'Ctl', 'Tr_zscore', 'Ctl_zscore'])
    match_results_df['diff'] = np.abs(match_results_df['Tr_zscore']-match_results_df['Ctl_zscore'])
    print(match_results_df['diff'].max())
    return match_results_df

# %%
model1 = lgb.LGBMClassifier(**params1)
flag_oof, imp_df = get_pred(df, test, CFG.fold_target1, CFG.target_cols1, model1, isFlag=True)
# Out:
# ===============  FOLD : 0  ===============
# train period : 2009.0年10.0月 ～ 2020.0年2.0月
# valid period : 1999.0年11.0月 ～ 2009.0年12.0月
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [79]	valid_0's auc: 0.897229
# F1 Score : 0.4540389972144847
# Precision Score : 0.7652582159624414
# Recall Score 0.3227722772277228
# ===============  FOLD : 1  ===============
# <ipython-input-24-45c411134384>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds["Zscore"] = predict_proba[:,1]
# <ipython-input-24-45c411134384>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds[f"{pred_name}_pred"] = pred
# train period : 1999.0年11.0月 ～ 2020.0年2.0月
# valid period : 2009.0年10.0月 ～ 2010.0年6.0月
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [64]	valid_0's auc: 0.964354
# F1 Score : 0.9300911854103343
# Precision Score : 0.9522821576763485
# Recall Score 0.9089108910891089
# ===============  FOLD : 2  ===============
# <ipython-input-24-45c411134384>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds["Zscore"] = predict_proba[:,1]
# <ipython-input-24-45c411134384>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds[f"{pred_name}_pred"] = pred
# train period : 1999.0年11.0月 ～ 2020.0年2.0月
# valid period : 2009.0年12.0月 ～ 2010.0年9.0月
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [74]	valid_0's auc: 0.962172
# F1 Score : 0.5542699724517907
# Precision Score : 0.383969465648855
# Recall Score 0.996039603960396
# ===============  FOLD : 3  ===============
# <ipython-input-24-45c411134384>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds["Zscore"] = predict_proba[:,1]
# <ipython-input-24-45c411134384>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds[f"{pred_name}_pred"] = pred
# train period : 1999.0年11.0月 ～ 2020.0年2.0月
# valid period : 2010.0年7.0月 ～ 2011.0年4.0月
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [89]	valid_0's auc: 0.920067
# <ipython-input-24-45c411134384>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds["Zscore"] = predict_proba[:,1]
# <ipython-input-24-45c411134384>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds[f"{pred_name}_pred"] = pred
# F1 Score : 0.5922865013774105
# Precision Score : 0.9684684684684685
# Recall Score 0.42658730158730157
# ===============  FOLD : 4  ===============
# train period : 1999.0年11.0月 ～ 2020.0年2.0月
# valid period : 2011.0年4.0月 ～ 2019.0年9.0月
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [8]	valid_0's auc: 0.862461
# F1 Score : 0.5407725321888412
# Precision Score : 0.9742268041237113
# Recall Score 0.37425742574257426
# ===============  FOLD : 5  ===============
# <ipython-input-24-45c411134384>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds["Zscore"] = predict_proba[:,1]
# <ipython-input-24-45c411134384>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds[f"{pred_name}_pred"] = pred
# train period : 1999.0年11.0月 ～ 2020.0年2.0月
# valid period : 2011.0年9.0月 ～ 2019.0年10.0月
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [93]	valid_0's auc: 0.999993
# <ipython-input-24-45c411134384>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds["Zscore"] = predict_proba[:,1]
# <ipython-input-24-45c411134384>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds[f"{pred_name}_pred"] = pred
# F1 Score : 0.9777347531461761
# Precision Score : 0.9564393939393939
# Recall Score 1.0
# ===============  FOLD : 6  ===============
# train period : 1999.0年11.0月 ～ 2020.0年2.0月
# valid period : 2019.0年8.0月 ～ 2019.0年10.0月
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [27]	valid_0's auc: 1
# <ipython-input-24-45c411134384>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds["Zscore"] = predict_proba[:,1]
# <ipython-input-24-45c411134384>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds[f"{pred_name}_pred"] = pred
# F1 Score : 0.9950248756218906
# Precision Score : 1.0
# Recall Score 0.9900990099009901
# ===============  FOLD : 7  ===============
# train period : 1999.0年11.0月 ～ 2019.0年10.0月
# valid period : 2019.0年10.0月 ～ 2020.0年2.0月
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [132]	valid_0's auc: 0.99997
# <ipython-input-24-45c411134384>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds["Zscore"] = predict_proba[:,1]
# <ipython-input-24-45c411134384>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds[f"{pred_name}_pred"] = pred
# F1 Score : 0.9960474308300395
# Precision Score : 0.9940828402366864
# Recall Score 0.998019801980198
#              feature  importance
# 306           mesh20    0.173333
# 65          sst_diff    0.081172
# 8         river_dist    0.062799
# 235            month    0.059373
# 62               lat    0.052047
# 275          sst_ymd    0.049329
# 74   Salinity_annual    0.043835
# 47     hist_warm_sst    0.039464
# 213       sst_annual    0.037514
# 292    hist_cold_sst    0.033260
# 53          warm_sst    0.031370
# 202       river_area    0.030838
# 217              lon    0.026053
# 262         cold_sst    0.024044
# 138    Date_Acquired    0.018787
# 261     coastal_dist    0.012583
# 140    aicial_length    0.012347
# 179            fetch    0.011815
# 20      coast_length    0.009098
# 176     sunElevation    0.008330
# 182       sunAzimuth    0.007975
# 0              TIRS2    0.006971
# 227          MIN_WVP    0.005908
# 48           MAX_WVP    0.005671
# 263            TIRS1    0.004785
# 128            depth    0.004372
# 219          MED_Bcc    0.004135
# 125          MAX_MVI    0.003545
# 1       beach_length    0.003308
# 269         MED_GVMI    0.002658
# 107         MED_MGVI    0.002422
# 112        VARIgreen    0.002422
# 171        MED_NDFI2    0.002363
# 203  MED_Chlred_edge    0.002304
# 228         MAX_NDSI    0.002304
# F1 Score : 0.7599749843652283
# Precision Score : 0.7679474216380182
# Recall Score 0.7521663778162911

# %%
imp_mean = imp_df.importance.mean()
imp_std = imp_df.importance.std()

thresh = imp_mean + imp_std*2
remove_features = imp_df.loc[imp_df.importance>thresh].feature.tolist()
print(remove_features)
features = [col for col in features if col not in remove_features]
# Out:
# ['mesh20', 'sst_diff', 'river_dist', 'month', 'lat', 'sst_ymd', 'Salinity_annual', 'hist_warm_sst', 'sst_annual', 'hist_cold_sst', 'warm_sst', 'river_area']

# %%
flag_oof, imp_df = get_pred(df, test, CFG.fold_target1, CFG.target_cols1, model1, isFlag=True)
# Out:
# ===============  FOLD : 0  ===============
# train period : 2009.0年10.0月 ～ 2020.0年2.0月
# valid period : 1999.0年11.0月 ～ 2009.0年12.0月
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [55]	valid_0's auc: 0.883989
# F1 Score : 0.37681159420289856
# Precision Score : 0.562992125984252
# Recall Score 0.28316831683168314
# ===============  FOLD : 1  ===============
# <ipython-input-24-45c411134384>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds["Zscore"] = predict_proba[:,1]
# <ipython-input-24-45c411134384>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds[f"{pred_name}_pred"] = pred
# train period : 1999.0年11.0月 ～ 2020.0年2.0月
# valid period : 2009.0年10.0月 ～ 2010.0年6.0月
# Training until validation scores don't improve for 50 rounds.
# [200]	valid_0's auc: 0.917731
# Early stopping, best iteration is:
# [166]	valid_0's auc: 0.918404
# F1 Score : 0.7368421052631579
# Precision Score : 0.72552783109405
# Recall Score 0.7485148514851485
# ===============  FOLD : 2  ===============
# <ipython-input-24-45c411134384>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds["Zscore"] = predict_proba[:,1]
# <ipython-input-24-45c411134384>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds[f"{pred_name}_pred"] = pred
# train period : 1999.0年11.0月 ～ 2020.0年2.0月
# valid period : 2009.0年12.0月 ～ 2010.0年9.0月
# Training until validation scores don't improve for 50 rounds.
# [200]	valid_0's auc: 0.905478
# Early stopping, best iteration is:
# [282]	valid_0's auc: 0.908192
# <ipython-input-24-45c411134384>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds["Zscore"] = predict_proba[:,1]
# <ipython-input-24-45c411134384>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds[f"{pred_name}_pred"] = pred
# F1 Score : 0.7104851330203442
# Precision Score : 0.5873221216041398
# Recall Score 0.899009900990099
# ===============  FOLD : 3  ===============
# train period : 1999.0年11.0月 ～ 2020.0年2.0月
# valid period : 2010.0年7.0月 ～ 2011.0年4.0月
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [81]	valid_0's auc: 0.772174
# F1 Score : 0.5623836126629423
# Precision Score : 0.5298245614035088
# Recall Score 0.5992063492063492
# ===============  FOLD : 4  ===============
# <ipython-input-24-45c411134384>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds["Zscore"] = predict_proba[:,1]
# <ipython-input-24-45c411134384>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds[f"{pred_name}_pred"] = pred
# train period : 1999.0年11.0月 ～ 2020.0年2.0月
# valid period : 2011.0年4.0月 ～ 2019.0年9.0月
# Training until validation scores don't improve for 50 rounds.
# [200]	valid_0's auc: 0.783693
# [400]	valid_0's auc: 0.82027
# Early stopping, best iteration is:
# [380]	valid_0's auc: 0.82027
# <ipython-input-24-45c411134384>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds["Zscore"] = predict_proba[:,1]
# <ipython-input-24-45c411134384>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds[f"{pred_name}_pred"] = pred
# F1 Score : 0.536376604850214
# Precision Score : 0.9591836734693877
# Recall Score 0.3722772277227723
# ===============  FOLD : 5  ===============
# train period : 1999.0年11.0月 ～ 2020.0年2.0月
# valid period : 2011.0年9.0月 ～ 2019.0年10.0月
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [125]	valid_0's auc: 0.99766
# <ipython-input-24-45c411134384>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds["Zscore"] = predict_proba[:,1]
# <ipython-input-24-45c411134384>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds[f"{pred_name}_pred"] = pred
# F1 Score : 0.957345971563981
# Precision Score : 0.9181818181818182
# Recall Score 1.0
# ===============  FOLD : 6  ===============
# train period : 1999.0年11.0月 ～ 2020.0年2.0月
# valid period : 2019.0年8.0月 ～ 2019.0年10.0月
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [141]	valid_0's auc: 0.99995
# <ipython-input-24-45c411134384>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds["Zscore"] = predict_proba[:,1]
# <ipython-input-24-45c411134384>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds[f"{pred_name}_pred"] = pred
# F1 Score : 0.9921259842519684
# Precision Score : 0.9863013698630136
# Recall Score 0.998019801980198
# ===============  FOLD : 7  ===============
# train period : 1999.0年11.0月 ～ 2019.0年10.0月
# valid period : 2019.0年10.0月 ～ 2020.0年2.0月
# Training until validation scores don't improve for 50 rounds.
# [200]	valid_0's auc: 0.999555
# Early stopping, best iteration is:
# [324]	valid_0's auc: 0.999678
# <ipython-input-24-45c411134384>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds["Zscore"] = predict_proba[:,1]
# <ipython-input-24-45c411134384>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds[f"{pred_name}_pred"] = pred
# F1 Score : 0.9811694747274529
# Precision Score : 0.9821428571428571
# Recall Score 0.9801980198019802
#              feature  importance
# 209              lon    0.113753
# 253         cold_sst    0.094461
# 173            fetch    0.048239
# 252     coastal_dist    0.024248
# 132    Date_Acquired    0.020665
# 134    aicial_length    0.020150
# 219          MIN_WVP    0.017940
# 1       beach_length    0.013691
# 119          MAX_MVI    0.013369
# 122            depth    0.011309
# 46           MAX_WVP    0.011116
# 0              TIRS2    0.010965
# 254            TIRS1    0.010729
# 190          MED_WVP    0.010686
# 176       sunAzimuth    0.010300
# 19      coast_length    0.010171
# 170     sunElevation    0.009099
# 121           MAX_CI    0.008905
# 131          MIN_AOT    0.008862
# 127          MED_MVI    0.008648
# 3           MAX_MNSI    0.008047
# 174          MIN_MVI    0.007017
# 151          MIN_BGI    0.006459
# 47          MED_NBR2    0.006266
# 218  MAX_MCARI_MTVI2    0.005751
# 175          MED_BOA    0.005665
# 193          MED_AOT    0.005601
# 165        MED_NDFI2    0.005536
# 23   MAX_Chlred_edge    0.005193
# 69          MAX_GVMI    0.004936
# 22          MAX_NBR2    0.004893
# 229          MAX_AVI    0.004850
# 292         MIN_MYVI    0.004721
# 82         MED_MIRBI    0.004699
# 260         MED_GVMI    0.004571
# F1 Score : 0.7499368527405911
# Precision Score : 0.7654034544985822
# Recall Score 0.7350829413221094

# %%
flag_df = flag_oof.loc[flag_oof.adv_flag==0]
z_mean = flag_df.Zscore.mean()
z_std = flag_df.Zscore.std()
z_thresh = z_mean - z_std*.43
flag_df = flag_df.loc[flag_df.Zscore>z_thresh]
print(flag_df.shape)
print(flag_df.cover.isnull().sum())
# Out:
# (14140, 3472)
# 0

# %%
fig, axes = plt.subplots(8, 1, figsize=(12, 12))

flag_df = flag_df.sort_values("year-month").reset_index(drop=True)

folds = KFold(n_splits=8,shuffle=False)

for i, (train_index, test_index) in enumerate(folds.split(flag_df)):

    #sns.lineplot(data=train, x='year-month', y='cover', ax=axes[i], label='original')
    # 学習用データを描く
    sns.lineplot(data=flag_df.iloc[train_index], x='year-month', y='cover', ax=axes[i], label='train')
    # テスト用データを描く
    sns.lineplot(data=flag_df.iloc[test_index], x='year-month', y='cover', ax=axes[i], label='test')

# グラフを表示する
plt.legend()
plt.show()

# %%
#match_results_df = matching(flag_oof, z_col='Zscore', tr_col='adv_flag', match_id='id')
#display(match_results_df)

# %%
#match_id = match_results_df.Ctl.tolist()
#match_train = train[train["id"].isin(match_id)].reset_index(drop=True)
#display(match_train)

# %%
model2 = lgb.LGBMRegressor(**params2)
oof_df, test_pred = get_pred(flag_df, test, CFG.fold_target3, CFG.target_cols2, model2)
# Out:
# fold
# 0    1768
# 1    1768
# 2    1768
# 3    1768
# 4    1767
# 5    1767
# 6    1767
# 7    1767
# dtype: int64
# ===============  FOLD : 0  ===============
# train period : 2009.0年10.0月 ～ 2020.0年2.0月
# valid period : 1999.0年11.0月 ～ 2009.0年10.0月
# Training until validation scores don't improve for 50 rounds.
# [200]	valid_0's rmse: 0.232207
# [400]	valid_0's rmse: 0.230537
# Early stopping, best iteration is:
# [386]	valid_0's rmse: 0.230407
# <ipython-input-24-45c411134384>:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds[f"{pred_name}_pred"] = model.predict(valid_X)
# RMSE 0.23040680493258736
# ===============  FOLD : 1  ===============
# train period : 1999.0年11.0月 ～ 2020.0年2.0月
# valid period : 2009.0年10.0月 ～ 2009.0年12.0月
# Training until validation scores don't improve for 50 rounds.
# [200]	valid_0's rmse: 0.136067
# [400]	valid_0's rmse: 0.133896
# Early stopping, best iteration is:
# [534]	valid_0's rmse: 0.133167
# <ipython-input-24-45c411134384>:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds[f"{pred_name}_pred"] = model.predict(valid_X)
# RMSE 0.13316678311991037
# ===============  FOLD : 2  ===============
# train period : 1999.0年11.0月 ～ 2020.0年2.0月
# valid period : 2009.0年12.0月 ～ 2010.0年9.0月
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [101]	valid_0's rmse: 0.0963928
# RMSE 0.09639280979463238
# ===============  FOLD : 3  ===============
# <ipython-input-24-45c411134384>:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds[f"{pred_name}_pred"] = model.predict(valid_X)
# train period : 1999.0年11.0月 ～ 2020.0年2.0月
# valid period : 2010.0年9.0月 ～ 2011.0年4.0月
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [24]	valid_0's rmse: 0.132618
# RMSE 0.13261796637692122
# ===============  FOLD : 4  ===============
# <ipython-input-24-45c411134384>:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds[f"{pred_name}_pred"] = model.predict(valid_X)
# train period : 1999.0年11.0月 ～ 2020.0年2.0月
# valid period : 2011.0年4.0月 ～ 2011.0年9.0月
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [25]	valid_0's rmse: 0.0704866
# RMSE 0.07048657786006063
# ===============  FOLD : 5  ===============
# <ipython-input-24-45c411134384>:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds[f"{pred_name}_pred"] = model.predict(valid_X)
# train period : 1999.0年11.0月 ～ 2020.0年2.0月
# valid period : 2011.0年9.0月 ～ 2019.0年8.0月
# Training until validation scores don't improve for 50 rounds.
# [200]	valid_0's rmse: 0.147978
# Early stopping, best iteration is:
# [320]	valid_0's rmse: 0.147135
# <ipython-input-24-45c411134384>:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds[f"{pred_name}_pred"] = model.predict(valid_X)
# RMSE 0.14713460109231047
# ===============  FOLD : 6  ===============
# train period : 1999.0年11.0月 ～ 2020.0年2.0月
# valid period : 2019.0年8.0月 ～ 2019.0年10.0月
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [106]	valid_0's rmse: 0.20823
# RMSE 0.20823037194230742
# ===============  FOLD : 7  ===============
# <ipython-input-24-45c411134384>:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds[f"{pred_name}_pred"] = model.predict(valid_X)
# train period : 1999.0年11.0月 ～ 2019.0年10.0月
# valid period : 2019.0年10.0月 ～ 2020.0年2.0月
# Training until validation scores don't improve for 50 rounds.
# [200]	valid_0's rmse: 0.211536
# [400]	valid_0's rmse: 0.21015
# Early stopping, best iteration is:
# [394]	valid_0's rmse: 0.210005
# <ipython-input-24-45c411134384>:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_folds[f"{pred_name}_pred"] = model.predict(valid_X)
# RMSE 0.21000520514565885
#              feature  importance
# 209              lon    0.014550
# 121           MAX_CI    0.014356
# 173            fetch    0.013933
# 122            depth    0.013351
# 0              TIRS2    0.010176
# 253         cold_sst    0.009788
# 127          MED_MVI    0.008713
# 183         MIN_GARI    0.008554
# 132    Date_Acquired    0.008501
# 106        VARIgreen    0.008448
# 119          MAX_MVI    0.008060
# 190          MED_WVP    0.008042
# 254            TIRS1    0.007989
# 1       beach_length    0.007937
# 35            MIN_IF    0.007831
# 268          MAX_GLI    0.007549
# 151          MIN_BGI    0.007390
# 219          MIN_WVP    0.006755
# 269          MED_mSR    0.006649
# 252     coastal_dist    0.006631
# 22          MAX_NBR2    0.006631
# 53           MAX_BGI    0.006596
# 246        MIN_MIRBI    0.006543
# 102        MAX_NDFI2    0.006526
# 192         MIN_NBR2    0.006508
# 244           MAX_IF    0.006473
# 47          MED_NBR2    0.006420
# 154         MED_GARI    0.006384
# 103          MED_BGI    0.006296
# 36   MIN_MCARI_MTVI2    0.006279
# 228         MED_MNSI    0.006208
# 129              GLI    0.006138
# 60           MAX_BOA    0.006102
# 19      coast_length    0.006102
# 46           MAX_WVP    0.006067
# RMSE 0.1627014811353648

# %%
cover_max = train.cover.max()
_oof = oof_df.copy()
_oof["pred"] = _oof["_pred"]
_oof["pred"] = _oof["pred"].apply(lambda x: x if x>0 else 0)
_oof["pred"] = _oof["pred"].apply(lambda x: x if x<1 else cover_max)
get_score(_oof["cover"], _oof["pred"])
# Out:
# RMSE 0.16267891905068907

# %%
plt.hist(_oof.pred, label='pred', bins=25, edgecolor='white', alpha=.6)
plt.hist(_oof.cover, label="label", bins=25, edgecolor='white', alpha=.6)
plt.xlabel("Pred")
plt.legend()
plt.show()

# %%
pred_df = test.copy()
pred_df["pred"] = np.mean(test_pred, axis=1)

pred_df = pred_df.sort_index()
pred_df
# Out:
#         id        lat         lon   area  \
# 0        0  24.352222  124.202674   20.0
# 1        1  24.420028  124.078583   20.0
# 2        2  26.494197  127.836013  100.0
# 3        3  26.183639  127.319361   20.0
# 4        4  24.761089  125.269009   20.0
# ...    ...        ...         ...    ...
# 4034  4034  26.702075  127.873347   20.0
# 4035  4035  24.337028  124.232694   20.0
# 4036  4036  26.493121  127.839918  100.0
# 4037  4037  24.068778  123.804194   20.0
# 4038  4038  24.791766  125.250825   20.0
#
#                                                     YMD    year  month  \
# 0                                               2002.12  2002.0   12.0
# 1                                              20100723  2010.0    7.0
# 2     2004.2.20-2004.2.22,2004.2.27-2004.2.29,2004.3...  2004.0    2.0
# 3                                              20100805  2010.0    8.0
# 4                                                   NaN  2019.0   10.0
# ...                                                 ...     ...    ...
# 4034                                                NaN  2019.0    9.0
# 4035                                           20101122  2010.0   11.0
# 4036  2004.2.20-2004.2.22,2004.2.27-2004.2.29,2004.3...  2004.0    2.0
# 4037                                           20110415  2011.0    4.0
# 4038                                                NaN  2019.0   10.0
#
#       depth_original  cliff_length  aicial_length  ...  MIN_PPR_2020  \
# 0                0.5      0.000000     725.621704  ...     -0.066356
# 1                NaN      0.000000       0.000000  ...     -0.291240
# 2               13.8     73.183418      80.595177  ...     -0.318454
# 3                NaN      0.000000       0.000000  ...     -0.320391
# 4               -0.5      0.000000      34.796036  ...     -0.231658
# ...              ...           ...            ...  ...           ...
# 4034             0.4      0.000000      20.594961  ...     -0.187582
# 4035             NaN      0.000000       0.000000  ...     -0.264021
# 4036             0.1     76.439651     133.127228  ...     -0.123194
# 4037             NaN     73.660492       0.000000  ...     -0.276085
# 4038             0.2      0.000000      46.460155  ...     -0.086155
#
#       MIN_PSNDc2_2020  MIN_RDVI_2020  MIN_IF_2020  MIN_SLAVI_2020  \
# 0           -0.560810      -3.203797     4.297234      926.905329
# 1           -0.824888      -2.222276     2.263106       57.661693
# 2           -0.861477      -2.060505     2.099250       42.672829
# 3           -0.863338      -2.708627   -10.433323       45.061952
# 4           -0.824787      -5.249625     2.563503       80.374689
# ...               ...            ...          ...             ...
# 4034        -0.861148      -3.207146     3.633575       60.936945
# 4035        -0.833596      -2.385447     2.495430       75.231230
# 4036        -0.843974      -4.397375     4.403977      117.513676
# 4037        -0.788681      -3.821984     2.203933      121.654726
# 4038        -0.907907      -5.638793     7.080204      128.096108
#
#       MIN_SIPI2_2020  MIN_VARIgreen_2020   mesh20  adv_flag      pred
# 0           1.669992            0.194766  3624_20         1  0.131147
# 1           4.274851          -79.273275  3624_20         1  0.102891
# 2           5.655713           -2.061417  3927_23         1  0.061988
# 3           1.546086          -14.527890  3927_11         1  0.045025
# 4           1.827876           -6.335208  3725_01         1  0.198253
# ...              ...                 ...      ...       ...       ...
# 4034        3.053976          -28.354402  4027_03         1  0.067872
# 4035        3.946128           -2.112646  3624_20         1  0.048858
# 4036        1.904304            0.601280  3927_23         1  0.246364
# 4037        2.282056           -2.029225  3623_03         1  0.095471
# 4038        1.783276            0.646303  3725_01         1  0.290533
#
# [4039 rows x 3466 columns]

# %%
pred_df["pred"] = pred_df["pred"].apply(lambda x: x if x>0 else 0)
pred_df["pred"] = pred_df["pred"].apply(lambda x: x if x<1 else 1)
pred_df[["pred"]].to_csv(os.path.join(OUTPUT_DIR, f'submit_{CFG.model}_seed{CFG.seed}_ver{CFG.ver}.csv'), header=False)

plt.hist(pred_df.pred,bins=25,edgecolor='white')
plt.xlabel("Pred")
plt.show()

display(pred_df)
# Out:
#         id        lat         lon   area  \
# 0        0  24.352222  124.202674   20.0
# 1        1  24.420028  124.078583   20.0
# 2        2  26.494197  127.836013  100.0
# 3        3  26.183639  127.319361   20.0
# 4        4  24.761089  125.269009   20.0
# ...    ...        ...         ...    ...
# 4034  4034  26.702075  127.873347   20.0
# 4035  4035  24.337028  124.232694   20.0
# 4036  4036  26.493121  127.839918  100.0
# 4037  4037  24.068778  123.804194   20.0
# 4038  4038  24.791766  125.250825   20.0
#
#                                                     YMD    year  month  \
# 0                                               2002.12  2002.0   12.0
# 1                                              20100723  2010.0    7.0
# 2     2004.2.20-2004.2.22,2004.2.27-2004.2.29,2004.3...  2004.0    2.0
# 3                                              20100805  2010.0    8.0
# 4                                                   NaN  2019.0   10.0
# ...                                                 ...     ...    ...
# 4034                                                NaN  2019.0    9.0
# 4035                                           20101122  2010.0   11.0
# 4036  2004.2.20-2004.2.22,2004.2.27-2004.2.29,2004.3...  2004.0    2.0
# 4037                                           20110415  2011.0    4.0
# 4038                                                NaN  2019.0   10.0
#
#       depth_original  cliff_length  aicial_length  ...  MIN_PPR_2020  \
# 0                0.5      0.000000     725.621704  ...     -0.066356
# 1                NaN      0.000000       0.000000  ...     -0.291240
# 2               13.8     73.183418      80.595177  ...     -0.318454
# 3                NaN      0.000000       0.000000  ...     -0.320391
# 4               -0.5      0.000000      34.796036  ...     -0.231658
# ...              ...           ...            ...  ...           ...
# 4034             0.4      0.000000      20.594961  ...     -0.187582
# 4035             NaN      0.000000       0.000000  ...     -0.264021
# 4036             0.1     76.439651     133.127228  ...     -0.123194
# 4037             NaN     73.660492       0.000000  ...     -0.276085
# 4038             0.2      0.000000      46.460155  ...     -0.086155
#
#       MIN_PSNDc2_2020  MIN_RDVI_2020  MIN_IF_2020  MIN_SLAVI_2020  \
# 0           -0.560810      -3.203797     4.297234      926.905329
# 1           -0.824888      -2.222276     2.263106       57.661693
# 2           -0.861477      -2.060505     2.099250       42.672829
# 3           -0.863338      -2.708627   -10.433323       45.061952
# 4           -0.824787      -5.249625     2.563503       80.374689
# ...               ...            ...          ...             ...
# 4034        -0.861148      -3.207146     3.633575       60.936945
# 4035        -0.833596      -2.385447     2.495430       75.231230
# 4036        -0.843974      -4.397375     4.403977      117.513676
# 4037        -0.788681      -3.821984     2.203933      121.654726
# 4038        -0.907907      -5.638793     7.080204      128.096108
#
#       MIN_SIPI2_2020  MIN_VARIgreen_2020   mesh20  adv_flag      pred
# 0           1.669992            0.194766  3624_20         1  0.131147
# 1           4.274851          -79.273275  3624_20         1  0.102891
# 2           5.655713           -2.061417  3927_23         1  0.061988
# 3           1.546086          -14.527890  3927_11         1  0.045025
# 4           1.827876           -6.335208  3725_01         1  0.198253
# ...              ...                 ...      ...       ...       ...
# 4034        3.053976          -28.354402  4027_03         1  0.067872
# 4035        3.946128           -2.112646  3624_20         1  0.048858
# 4036        1.904304            0.601280  3927_23         1  0.246364
# 4037        2.282056           -2.029225  3623_03         1  0.095471
# 4038        1.783276            0.646303  3725_01         1  0.290533
#
# [4039 rows x 3466 columns]
