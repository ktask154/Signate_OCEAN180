# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

DIR = "/content/drive/MyDrive/Competitions/Signate/OCEAN180"
INPUT_DIR = os.path.join(DIR,"input")
OUTPUT_DIR = os.path.join(DIR,"output")
OUTPUT_DF_DIR = os.path.join(OUTPUT_DIR,"DATAFRAME")

if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df_ver = 40
train = pd.read_csv(os.path.join(INPUT_DIR,"train_data.csv"))
test = pd.read_csv(os.path.join(INPUT_DIR,"test_data.csv"))
#train = pd.read_csv(os.path.join(OUTPUT_DF_DIR,f"exp{df_ver}_train.csv"))
#test = pd.read_csv(os.path.join(OUTPUT_DF_DIR,f"exp{df_ver}_test.csv"))
sample_sub = pd.read_csv(os.path.join(INPUT_DIR,"submit_example.csv"), header=None)

features_df = pd.read_csv(os.path.join(OUTPUT_DF_DIR,f"exp{df_ver}_imp.csv"))


print(train.shape)
display(train.head(3))

print(test.shape)
display(test.head(3))

print(sample_sub.shape)
display(sample_sub.head(3))
# Out:
# (14140, 3465)
#    Unnamed: 0        lat         lon  area                 YMD    year  month  \
# 0           0  24.989139  125.243167  20.0            20110926  2011.0    9.0
# 1           1  26.996172  127.912024  40.0  2009.7.6-2009.7.28  2009.0    7.0
# 2           2  26.363556  127.735139  20.0            20091014  2009.0   10.0
#
#    cover  depth_original  cliff_length  ...  MIN_NormG_2020  MIN_NormR_2020  \
# 0  0.050             NaN           0.0  ...        0.507961        0.287288
# 1  0.725             NaN           0.0  ...        0.353645        0.245048
# 2  0.025             NaN           0.0  ...        0.579204        0.281260
#
#    MIN_PPR_2020  MIN_PSNDc2_2020  MIN_RDVI_2020  MIN_IF_2020  MIN_SLAVI_2020  \
# 0     -0.278071        -0.808075      -2.341663     2.353039       95.142525
# 1     -0.100556        -0.771423      -3.282602     4.672225      174.767501
# 2     -0.191884        -0.853730      -3.160207     3.324236       62.711236
#
# ...

# %%
print("number of target values:", train.cover.nunique())
# Out:
# number of target values: 143

# %%
train.cover.value_counts()
# Out:
# 0.0500    4878
# 0.0000    2226
# 0.0250    1927
# 0.6250     718
# 0.3750     630
#           ...
# 0.3650       1
# 0.2666       1
# 0.3270       1
# 0.4650       1
# 0.0275       1
# Name: cover, Length: 143, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_subplot()
train.year.value_counts().sort_index().plot(kind="bar",ax=ax,color='b',alpha=.6)
test.year.value_counts().sort_index().plot(kind="bar",ax=ax,color='g',alpha=.6)
plt.show()
